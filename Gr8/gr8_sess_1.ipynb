# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# ...

# %%
df.sample(3)
# Out:
#        ResponseId                      MainBranch  \
# 51490       51491  I am a developer by profession
# 29312       29313  I am a developer by profession
# 73216       73217  I am a developer by profession
#
#                                               Employment  \
# 51490                                Employed, full-time
# 29312  Not employed, but looking for work;Independent...
# 73216                                Employed, full-time
#
#                                  RemoteWork  \
# 51490                          Fully remote
# 29312  Hybrid (some remote, some in-person)
# 73216                          Fully remote
#
#                                         CodingActivities  \
# 51490                                              Hobby
# 29312  Contribute to open-source projects;Freelance/c...
# 73216                     Hobby;Bootstrapping a business
#
#                                                  EdLevel  \
# ...

# %%
df.describe(include = 'object')
# Out:
#                             MainBranch           Employment    RemoteWork  \
# count                            73268                71709         58958
# unique                               6                  103             3
# top     I am a developer by profession  Employed, full-time  Fully remote
# freq                             53507                42962         25341
#
#        CodingActivities                                       EdLevel  \
# count             58899                                         71571
# unique               63                                             9
# top               Hobby  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# freq              18118                                         30276
#
#                                       LearnCode  \
# count                                     71580
# unique                                      737
# top     School (i.e., University, College, etc)
# ...

# %%
df.dtypes
# Out:
# ResponseId               int64
# MainBranch              object
# Employment              object
# RemoteWork              object
# CodingActivities        object
#                         ...
# TrueFalse_2             object
# TrueFalse_3             object
# SurveyLength            object
# SurveyEase              object
# ConvertedCompYearly    float64
# Length: 79, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.Country.value_counts()
# Out:
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Burkina Faso                                                1
# Saint Kitts and Nevis                                       1
# Monaco                                                      1
# Solomon Islands                                             1
# Brunei Darussalam                                           1
# Name: Country, Length: 180, dtype: int64

# %%
df.isnull().sum()
# Out:
# ResponseId                 0
# MainBranch                 0
# Employment              1559
# RemoteWork             14310
# CodingActivities       14369
#                        ...
# TrueFalse_2            37553
# TrueFalse_3            37519
# SurveyLength            2824
# SurveyEase              2760
# ConvertedCompYearly    35197
# Length: 79, dtype: int64

# %%
df.query('Country == "India"')
# Out:
#        ResponseId                                         MainBranch  \
# 6               7                        I code primarily as a hobby
# 7               8                     I am a developer by profession
# 65             66                     I am a developer by profession
# 140           141                     I am a developer by profession
# 151           152                     I am a developer by profession
# ...           ...                                                ...
# 73184       73185                     I am a developer by profession
# 73193       73194  I used to be a developer by profession, but no...
# 73255       73256                     I am a developer by profession
# 73257       73258                              I am learning to code
# 73258       73259                     I am a developer by profession
#
#                                Employment  \
# 6                      Student, part-time
# 7      Not employed, but looking for work
# ...

# %%
df.eval('psudocomp = CompTotal/2')
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df.columns.isin(['CompTotal'])
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
df.loc[:, df.columns.isin(['CompTotal'])]
# Out:
#        CompTotal
# 0            NaN
# 1            NaN
# 2        32000.0
# 3        60000.0
# 4            NaN
# ...          ...
# 73263    60000.0
# 73264   107000.0
# 73265        NaN
# 73266    58500.0
# 73267        NaN
#
# [73268 rows x 1 columns]

# %%
df.groupby('Country')['CompTotal'].mean().sort_values(ascending=False)
# Out:
# Country
# Ecuador                     1.875000e+55
# United States of America    1.138952e+48
# Italy                       1.223990e+12
# Kyrgyzstan                  4.545455e+11
# Nigeria                     1.136584e+10
#                                 ...
# North Korea                          NaN
# Papua New Guinea                     NaN
# Saint Kitts and Nevis                NaN
# San Marino                           NaN
# Sierra Leone                         NaN
# Name: CompTotal, Length: 180, dtype: float64

# %%
df.groupby('Country')['CompTotal'].agg(['mean', 'count']).query('count > 1000').sort_values(by='count', ascending = False)
# Out:
#                                                             mean  count
# Country
# United States of America                            1.138952e+48   8780
# Germany                                             5.487846e+04   2925
# United Kingdom of Great Britain and Northern Ir...  6.748744e+04   2671
# India                                               1.693451e+06   2229
# Canada                                              1.259291e+05   1492
# France                                              5.022446e+04   1387
# Brazil                                              6.205287e+04   1291
# Spain                                               4.416284e+04   1004

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.groupby(['sex', 'day'])[['total_bill', 'tip']].agg(['mean', 'sum', 'count'])
# Out:
#             total_bill                      tip
#                   mean      sum count      mean     sum count
# sex    day
# Male   Thur  18.714667   561.44    30  2.980333   89.41    30
#        Fri   19.857000   198.57    10  2.693000   26.93    10
#        Sat   20.802542  1227.35    59  3.083898  181.95    59
#        Sun   21.887241  1269.46    58  3.220345  186.78    58
# Female Thur  16.715312   534.89    32  2.575625   82.42    32
#        Fri   14.145556   127.31     9  2.781111   25.03     9
#        Sat   19.680357   551.05    28  2.801786   78.45    28
#        Sun   19.872222   357.70    18  3.367222   60.61    18

# %%
tips.groupby(['sex', 'day']).agg(dict(total_bill = ['mean', 'count']))
# Out:
#             total_bill
#                   mean count
# sex    day
# Male   Thur  18.714667    30
#        Fri   19.857000    10
#        Sat   20.802542    59
#        Sun   21.887241    58
# Female Thur  16.715312    32
#        Fri   14.145556     9
#        Sat   19.680357    28
#        Sun   19.872222    18

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
pd.Categorical(values = tips.day, categories = ['Thur', 'Fri', 'Sat', 'Sun'])
# Out:
# ['Sun', 'Sun', 'Sun', 'Sun', 'Sun', ..., 'Sat', 'Sat', 'Sat', 'Sat', 'Thur']
# Length: 244
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.pivot_table(index='day', columns='smoker', values='total_bill', aggfunc='mean')
# Out:
# smoker        Yes         No
# day
# Thur    19.190588  17.113111
# Fri     16.813333  18.420000
# Sat     21.276667  19.661778
# Sun     24.120000  20.506667

# %%
pd.crosstab(index=tips.day, columns=[tips.sex, tips.smoker], values=tips.total_bill, aggfunc='count')
# Out:
# sex    Male     Female
# smoker  Yes  No    Yes  No
# day
# Thur     10  20      7  25
# Fri       8   2      7   2
# Sat      27  32     15  13
# Sun      15  43      4  14

# %%
df.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# ...

# %%
df.Country
# Out:
# 0                                                      NaN
# 1                                                   Canada
# 2        United Kingdom of Great Britain and Northern I...
# 3                                                   Israel
# 4                                 United States of America
#                                ...
# 73263                                              Nigeria
# 73264                             United States of America
# 73265                             United States of America
# 73266    United Kingdom of Great Britain and Northern I...
# 73267                                               Canada
# Name: Country, Length: 73268, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.Age
# Out:
# 0                    NaN
# 1                    NaN
# 2        25-34 years old
# 3        35-44 years old
# 4        25-34 years old
#               ...
# 73263    25-34 years old
# 73264    25-34 years old
# 73265    55-64 years old
# 73266    55-64 years old
# 73267    25-34 years old
# Name: Age, Length: 73268, dtype: object

# %%
df.LanguageHaveWorkedWith
# Out:
# 0                                                      NaN
# 1                                    JavaScript;TypeScript
# 2                        C#;C++;HTML/CSS;JavaScript;Python
# 3                             C#;JavaScript;SQL;TypeScript
# 4              C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
#                                ...
# 73263    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265                   HTML/CSS;JavaScript;PHP;Python;SQL
# 73266                                        C#;Delphi;VBA
# 73267          C#;JavaScript;Lua;PowerShell;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 73268, dtype: object

# %%
df.LanguageHaveWorkedWith.str.split(';', expand=True)
# Out:
#                0           1           2           3       4           5   \
# 0             NaN         NaN         NaN         NaN     NaN         NaN
# 1      JavaScript  TypeScript        None        None    None        None
# 2              C#         C++    HTML/CSS  JavaScript  Python        None
# 3              C#  JavaScript         SQL  TypeScript    None        None
# 4              C#    HTML/CSS  JavaScript         SQL   Swift  TypeScript
# ...           ...         ...         ...         ...     ...         ...
# 73263  Bash/Shell        Dart  JavaScript         PHP  Python         SQL
# 73264  Bash/Shell    HTML/CSS  JavaScript      Python     SQL        None
# 73265    HTML/CSS  JavaScript         PHP      Python     SQL        None
# 73266          C#      Delphi         VBA        None    None        None
# 73267          C#  JavaScript         Lua  PowerShell     SQL  TypeScript
#
#                6     7     8     9   ...    32    33    34    35    36    37  \
# ...

# %%
df.LanguageHaveWorkedWith.str.split(';').explode().value_counts()
# Out:
# JavaScript     46443
# HTML/CSS       39142
# SQL            35127
# Python         34155
# TypeScript     24752
# Java           23644
# Bash/Shell     20656
# C#             19883
# C++            16024
# PHP            14827
# C              13692
# PowerShell      8575
# Go              7922
# Rust            6625
# Kotlin          6507
# Dart            4648
# Ruby            4299
# Assembly        3887
# Swift           3489
# R               3308
# VBA             3185
# MATLAB          2913
# Lua             2867
# Groovy          2357
# Delphi          2311
# Scala           1837
# Objective-C     1698
# Perl            1644
# Haskell         1577
# Elixir          1528
# Julia           1084
# Clojure         1070
# Solidity        1031
# LISP             932
# F#               730
# Fortran          646
# Erlang           641
# APL              504
# COBOL            464
# SAS              435
# OCaml            422
# Crystal          340
# ...

# %%
df.Country.isnull().sum()
# Out:
# 1497

# %%
df.dropna(how = 'all', subset = ['Country'], inplace = False)
# Out:
#        ResponseId                                         MainBranch  \
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# 5               6  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 1                                    Employed, full-time
# ...

# %%
data = df.dropna(how = 'all', subset = ['Country'], inplace = False)

# %%
data.groupby(['Country'])['Country'].count()
# Out:
# Country
# Afghanistan                              69
# Albania                                  59
# Algeria                                  36
# Andorra                                  15
# Angola                                   12
#                                        ...
# Venezuela, Bolivarian Republic of...    119
# Viet Nam                                317
# Yemen                                    14
# Zambia                                   20
# Zimbabwe                                 30
# Name: Country, Length: 180, dtype: int64

# %%
data.groupby(['Country'])['Country'].count().sort_values(ascending=False)
# Out:
# Country
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
#                                                         ...
# Seychelles                                                  1
# Monaco                                                      1
# Solomon Islands                                             1
# Burkina Faso                                                1
# Djibouti                                                    1
# Name: Country, Length: 180, dtype: int64

# %%
data.groupby(['Country'])['Country'].count().nlargest(5)
# Out:
# Country
# United States of America                                13543
# India                                                    6639
# Germany                                                  5395
# United Kingdom of Great Britain and Northern Ireland     4190
# Canada                                                   2490
# Name: Country, dtype: int64

# %%
data.loc[data.Country.isin(data.groupby(['Country'])['Country'].count().nlargest(5).index), :]
# Out:
#        ResponseId                                         MainBranch  \
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 4               5                     I am a developer by profession
# 5               6  I am not primarily a developer, but I write co...
# 6               7                        I code primarily as a hobby
# ...           ...                                                ...
# 73262       73263                              I am learning to code
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 1                                    Employed, full-time
# ...

# %%
mac = pd.read_csv('bigmac.csv')

# %%
mac.sample(3)
# Out:
#        Date       Country  Price in US Dollars
# 427  7/2012  South Africa                 2.36
# 20   1/2016        Mexico                 2.81
# 201  7/2014     Sri Lanka                 2.69

# %%
mac.dtypes
# Out:
# Date                    object
# Country                 object
# Price in US Dollars    float64
# dtype: object

# %%
mac.Date.head()
# Out:
# 0    1/2016
# 1    1/2016
# 2    1/2016
# 3    1/2016
# 4    1/2016
# Name: Date, dtype: object

# %%
pd.to_datetime(mac.Date, format='%M/%Y')
# Out:
# 0     2016-01-01 00:01:00
# 1     2016-01-01 00:01:00
# 2     2016-01-01 00:01:00
# 3     2016-01-01 00:01:00
# 4     2016-01-01 00:01:00
#               ...
# 647   2010-01-01 00:01:00
# 648   2010-01-01 00:01:00
# 649   2010-01-01 00:01:00
# 650   2010-01-01 00:01:00
# 651   2010-01-01 00:01:00
# Name: Date, Length: 652, dtype: datetime64[ns]

# %%
pd.to_datetime(mac.Date, format='%M/%Y').dt.month_name()
# Out:
# 0      January
# 1      January
# 2      January
# 3      January
# 4      January
#         ...
# 647    January
# 648    January
# 649    January
# 650    January
# 651    January
# Name: Date, Length: 652, dtype: object

# %%
mac['Date'] = pd.to_datetime(mac.Date, format = '%M/%Y')

# %%
mac.dtypes
# Out:
# Date                   datetime64[ns]
# Country                        object
# Price in US Dollars           float64
# dtype: object

# %%
mac.set_index('Date', inplace=True)

# %%
mac = mac.select_dtypes('float')

# %%
mac.resample(rule='D').plot(kind = 'line')
# Out:
#                           Price in US Dollars
# Date
# 2010-01-01  AxesSubplot(0.125,0.2;0.775x0.68)
# 2010-01-02  AxesSubplot(0.125,0.2;0.775x0.68)
# 2010-01-03  AxesSubplot(0.125,0.2;0.775x0.68)
# 2010-01-04  AxesSubplot(0.125,0.2;0.775x0.68)
# 2010-01-05  AxesSubplot(0.125,0.2;0.775x0.68)
# ...                                       ...
# 2015-12-28  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-12-29  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-12-30  AxesSubplot(0.125,0.2;0.775x0.68)
# 2015-12-31  AxesSubplot(0.125,0.2;0.775x0.68)
# 2016-01-01  AxesSubplot(0.125,0.2;0.775x0.68)
#
# [2192 rows x 1 columns]

# %%
mac.resample('Y').count()
# Out:
#             Price in US Dollars
# Date
# 2010-12-31                   86
# 2011-12-31                   57
# 2012-12-31                  113
# 2013-12-31                  114
# 2014-12-31                  114
# 2015-12-31                  112
# 2016-12-31                   56

# %%
startups = pd.read_csv('50_Startups.csv')

# %%
startups.head(3)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39

# %%
startups.eval('pseudo_profit_6M = Profit/2')
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit  \
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
sny = startups.loc[startups.State == 'New York']
sfl = startups.query('State == "Florida"')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=38c7b80a-5e49-4d3b-bc61-2b426e98b218' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
