# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/sammy/Linux Folder/Sammy/raw_datasets/nba.csv')

# %%
df.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
df.shape
# Out:
# (458, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.describe(include = 'object')
# Out:
#                  Name                  Team Position Height   College
# count             457                   457      457    457       373
# unique            457                    30        5     18       118
# top     Avery Bradley  New Orleans Pelicans       SG    6-9  Kentucky
# freq                1                    19      102     59        22

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df[df.Name.isnull()]
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN

# %%
df.dropna(axis=0, how='all')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ### Notes
#
# df.head()
# df.tail()
# df.index
# df.columns
# df.describe(include = 'object')
# df.info
# df.to_numpy
# df.sort_index(axis=0, ascending=False)
# df.sort_values(by='col_name')
# df.at()
# df.iat()
# df.loc()
# df.iloc()
# df.T
# df.isnul().sum()
# pds.isnull().sum()
# df/pds.value_counts(normalize=True)
# df/pds.count()
# df.loc[:, ["A", "B"]]
# df.loc[~[filt], ["A", "B"]]
# df1.dropna(how="any", subset=[list of cols])
# df1.fillna(value=5)
# pd.isna(df1)
# df.mean()
# df.sub(s, axis="index")
# df.apply
# pds.map
# df.applymap
# pds.replace
# df.apply(np.cumsum)
# df.apply(lambda x: x.max() - x.min())
# s.str.lower()
# str.upper()
# str.title()
# unique
# nunique

# %%
df = pd.DataFrame(np.random.randn(10, 4))

pieces = [df[:3], df[3:7], df[7:]]

pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.412999 -0.632310 -0.184482  1.439095
# 1 -0.968612  0.377514  1.045055  0.088813
# 2  0.916647 -0.562296  0.623625 -1.010102
# 3 -0.299865  0.870202 -0.294495  0.015636
# 4 -0.476007  1.134606  1.077721 -0.323428
# 5  0.117172  2.016271  0.984409 -0.798401
# 6  0.071558 -0.700493  0.107450  0.306494
# 7  1.490654  0.430672  1.648929 -0.802414
# 8  0.662797 -0.002043  1.980744 -0.899791
# 9  1.391908 -2.588638 -0.680686  0.277813

# %%
df
# Out:
#           0         1         2         3
# 0  0.412999 -0.632310 -0.184482  1.439095
# 1 -0.968612  0.377514  1.045055  0.088813
# 2  0.916647 -0.562296  0.623625 -1.010102
# 3 -0.299865  0.870202 -0.294495  0.015636
# 4 -0.476007  1.134606  1.077721 -0.323428
# 5  0.117172  2.016271  0.984409 -0.798401
# 6  0.071558 -0.700493  0.107450  0.306494
# 7  1.490654  0.430672  1.648929 -0.802414
# 8  0.662797 -0.002043  1.980744 -0.899791
# 9  1.391908 -2.588638 -0.680686  0.277813

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
left = pd.DataFrame({"key": ["foo", "bar"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "bar"], "rval": [4, 5]})

pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
# DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False, validate=None)

# %% [markdown]
# DataFrame.update(other, join='left', overwrite=True, filter_func=None, errors='ignore')

# %% [markdown]
# DataFrame.append(other, ignore_index=False, verify_integrity=False, sort=False)

# %% [markdown]
# DataFrame.merge(right, how='inner', on=None, left_on=None, right_on=None, left_index=False, right_index=False, sort=False, suffixes=('_x', '_y'), copy=True, indicator=False, validate=None)

# %% [markdown]
# ##### Grouping
# By “group by” we are referring to a process involving one or more of the following steps:
#
# > Splitting the data into groups based on some criteria
#
# > Applying a function to each group independently
#
# > Combining the results into a data structure

# %%
df = pd.read_csv('/home/sammy/Linux Folder/Sammy/raw_datasets/nba.csv')

# %%
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df.groupby(['Team'])

# %%
df = pd.read_csv('/home/sammy/Linux Folder/Sammy/raw_datasets/survey_results_public.csv', index_col='Respondent')

# %%
df.head(3)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
df.rename(columns={'ConvertedComp': 'Salary'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'Salary', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
df.Salary
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: Salary, Length: 88883, dtype: float64

# %%
df.loc[:, ['SocialMedia']].value_counts(normalize=True).sort_values(ascending=False)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# dtype: float64

# %%
df.groupby(['Country'])

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States').head(3)
# Out:
#     Respondent                      MainBranch Hobbyist  \
# 3            4  I am a developer by profession       No
# 12          13  I am a developer by profession      Yes
# 21          22  I am a developer by profession      Yes
#
#                                           OpenSourcer  \
# 3                                               Never
# 12  Less than once a month but more than once per ...
# 21                            Less than once per year
#
#                                            OpenSource          Employment  \
# 3   The quality of OSS and closed source software ...  Employed full-time
# 12  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 21  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#           Country Student                                            EdLevel  \
# 3   United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
df.groupby(['Country']).get_group('India').head(3)
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 7            8             I code primarily as a hobby      Yes
# 9           10          I am a developer by profession      Yes
# 14          15  I am a student who is learning to code      Yes
#
#                    OpenSourcer  \
# 7      Less than once per year
# 9   Once a month or more often
# 14                       Never
#
#                                            OpenSource  \
# 7   OSS is, on average, of HIGHER quality than pro...
# 9   OSS is, on average, of HIGHER quality than pro...
# 14  OSS is, on average, of HIGHER quality than pro...
#
#                             Employment Country         Student  \
# 7   Not employed, but looking for work   India             NaN
# 9                   Employed full-time   India              No
# 14  Not employed, but looking for work   India  Yes, full-time
#
#                                               EdLevel  \
# ...

# %%
df.loc[(df['Country'] == 'India'), :].head(3)
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 7            8             I code primarily as a hobby      Yes
# 9           10          I am a developer by profession      Yes
# 14          15  I am a student who is learning to code      Yes
#
#                    OpenSourcer  \
# 7      Less than once per year
# 9   Once a month or more often
# 14                       Never
#
#                                            OpenSource  \
# 7   OSS is, on average, of HIGHER quality than pro...
# 9   OSS is, on average, of HIGHER quality than pro...
# 14  OSS is, on average, of HIGHER quality than pro...
#
#                             Employment Country         Student  \
# 7   Not employed, but looking for work   India             NaN
# 9                   Employed full-time   India              No
# 14  Not employed, but looking for work   India  Yes, full-time
#
#                                               EdLevel  \
# ...

# %%
df.loc[(df.Country == 'India'), ['SocialMedia']].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# dtype: int64

# %%
df.groupby(['Country'])['SocialMedia'].value_counts(normalize = True)
# Out:
# Country      SocialMedia
# Afghanistan  Facebook                    0.405405
#              YouTube                     0.243243
#              I don't use social media    0.162162
#              WhatsApp                    0.108108
#              Instagram                   0.027027
#                                            ...
# Zimbabwe     Facebook                    0.076923
#              YouTube                     0.076923
#              Instagram                   0.051282
#              LinkedIn                    0.051282
#              Reddit                      0.025641
# Name: SocialMedia, Length: 1220, dtype: float64

# %%
df.groupby(['Country'])['SocialMedia'].value_counts(normalize = True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: SocialMedia, dtype: float64

# %%
df.groupby(['Country'])['SocialMedia'].value_counts(normalize = True).loc[['China', 'India']]
# Out:
# Country  SocialMedia
# China    WeChat 微信                   0.670549
#          YouTube                     0.088186
#          Weibo 新浪微博                  0.069884
#          I don't use social media    0.044925
#          Twitter                     0.044925
#          Reddit                      0.019967
#          LinkedIn                    0.018303
#          Facebook                    0.013311
#          Instagram                   0.011647
#          Youku Tudou 优酷              0.011647
#          WhatsApp                    0.004992
#          VK ВКонта́кте               0.001664
# India    WhatsApp                    0.342379
#          YouTube                     0.208405
#          LinkedIn                    0.109355
#          Facebook                    0.096301
#          Instagram                   0.094126
#          Twitter                     0.062063
#          Reddit                      0.054162
#          I don't use social media    0.028627
# ...

# %%
df.groupby(['Country'])['Salary'].median().sort_values(ascending = False)
# Out:
# Country
# Liechtenstein                       811188.0
# San Marino                          301788.0
# Timor-Leste                         229500.0
# Andorra                             160931.0
# Democratic Republic of the Congo    110484.0
#                                       ...
# Papua New Guinea                         NaN
# Saint Kitts and Nevis                    NaN
# Sao Tome and Principe                    NaN
# Sierra Leone                             NaN
# Tonga                                    NaN
# Name: Salary, Length: 179, dtype: float64

# %%
df.groupby(['Country'])['Respondent'].count()
# Out:
# Country
# Afghanistan                              44
# Albania                                  86
# Algeria                                 134
# Andorra                                   7
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     88
# Viet Nam                                231
# Yemen                                    19
# Zambia                                   12
# Zimbabwe                                 39
# Name: Respondent, Length: 179, dtype: int64

# %%
df.groupby(['Country'])['Respondent'].count() >= 100
# Out:
# Country
# Afghanistan                             False
# Albania                                 False
# Algeria                                  True
# Andorra                                 False
# Angola                                  False
#                                         ...
# Venezuela, Bolivarian Republic of...    False
# Viet Nam                                 True
# Yemen                                   False
# Zambia                                  False
# Zimbabwe                                False
# Name: Respondent, Length: 179, dtype: bool

# %%
(df.groupby(['Country'])['Respondent'].count() >= 100).index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'United Kingdom', 'United Republic of Tanzania', 'United States',
#        'Uruguay', 'Uzbekistan', 'Venezuela, Bolivarian Republic of...',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country', length=179)

# %%
df.loc[(df['Country'].isin((df.groupby(['Country']).count() >= 100).index)), :]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88875       88182                                                NaN      Yes
# 88876       88212                                                NaN       No
# 88877       88282                                                NaN      Yes
# 88878       88377                                                NaN      Yes
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.loc[(df['Country'].isin((df.groupby(['Country']).count() >= 100).index)), :].groupby(['Country'])['Salary'].median().sort_values(ascending = False)
# Out:
# Country
# Liechtenstein                       811188.0
# San Marino                          301788.0
# Timor-Leste                         229500.0
# Andorra                             160931.0
# Democratic Republic of the Congo    110484.0
#                                       ...
# Papua New Guinea                         NaN
# Saint Kitts and Nevis                    NaN
# Sao Tome and Principe                    NaN
# Sierra Leone                             NaN
# Tonga                                    NaN
# Name: Salary, Length: 179, dtype: float64

# %%
df.loc[(df['Country'].isin((df.groupby(['Country']).count() >= 100).index)), :].groupby(['Country'])['Salary'].median().sort_values(ascending = False).loc[['Germany', 'India']]
# Out:
# Country
# Germany    63016.0
# India      10080.0
# Name: Salary, dtype: float64

# %%
country_grp = df.groupby(['Country'])
country_grp['Salary'].agg(['median', 'mean']).sort_values(by = ['median', 'mean'], ascending = [False, True])
# Out:
#                                     median      mean
# Country
# Liechtenstein                     811188.0  811188.0
# San Marino                        301788.0  301788.0
# Timor-Leste                       229500.0  229500.0
# Andorra                           160931.0  160931.0
# Democratic Republic of the Congo  110484.0  110484.0
# ...                                    ...       ...
# Papua New Guinea                       NaN       NaN
# Saint Kitts and Nevis                  NaN       NaN
# Sao Tome and Principe                  NaN       NaN
# Sierra Leone                           NaN       NaN
# Tonga                                  NaN       NaN
#
# [179 rows x 2 columns]

# %%
count_over100resp = (df.groupby(['Country'])['Respondent'].count() >= 100).index
filt = df['Country'].isin(count_over100resp)
filtered_df = df.loc[filt, ]

filtered_df.groupby(['Country'])['Salary'].agg(['median', 'mean'])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
filtered_df.groupby(['Country'])['Salary'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = (df['Country'] == 'India')
df.loc[filt].head(3)
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 7            8             I code primarily as a hobby      Yes
# 9           10          I am a developer by profession      Yes
# 14          15  I am a student who is learning to code      Yes
#
#                    OpenSourcer  \
# 7      Less than once per year
# 9   Once a month or more often
# 14                       Never
#
#                                            OpenSource  \
# 7   OSS is, on average, of HIGHER quality than pro...
# 9   OSS is, on average, of HIGHER quality than pro...
# 14  OSS is, on average, of HIGHER quality than pro...
#
#                             Employment Country         Student  \
# 7   Not employed, but looking for work   India             NaN
# 9                   Employed full-time   India              No
# 14  Not employed, but looking for work   India  Yes, full-time
#
#                                               EdLevel  \
# ...

# %%
df.loc[(df['Country'] == 'India'), 'LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
df.groupby('Country')['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
df.groupby('Country')['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python')).agg(sum)
# Out:
# 36443

# %%
df.groupby('Country')['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').value_counts(normalize = True))
# Out:
# Country
# Afghanistan  False    0.794872
#              True     0.205128
# Albania      False    0.722892
#              True     0.277108
# Algeria      False    0.682540
#                         ...
# Yemen        True     0.176471
# Zambia       False    0.666667
#              True     0.333333
# Zimbabwe     False    0.641026
#              True     0.358974
# Name: LanguageWorkedWith, Length: 335, dtype: float64

# %%
ppl_all = df.groupby('Country')['LanguageWorkedWith'].count() 
ppl_py = df.groupby('Country')['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
ppl_all
# Out:
# Country
# Afghanistan                              39
# Albania                                  83
# Algeria                                 126
# Andorra                                   7
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     87
# Viet Nam                                220
# Yemen                                    17
# Zambia                                   12
# Zimbabwe                                 39
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
ppl_py
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
pd.concat([ppl_all, ppl_py], axis=1)
# Out:
#                                       LanguageWorkedWith  LanguageWorkedWith
# Country
# Afghanistan                                           39                   8
# Albania                                               83                  23
# Algeria                                              126                  40
# Andorra                                                7                   0
# Angola                                                 4                   2
# ...                                                  ...                 ...
# Venezuela, Bolivarian Republic of...                  87                  28
# Viet Nam                                             220                  78
# Yemen                                                 17                   3
# Zambia                                                12                   4
# Zimbabwe                                              39                  14
#
# [179 rows x 2 columns]

# %%
data = pd.concat([ppl_all, ppl_py], axis='columns', sort=False)

data['calc'] = data.iloc[:, 1].div(data.iloc[:, 0])

# %%
data
# Out:
#                                       LanguageWorkedWith  LanguageWorkedWith  \
# Country
# Afghanistan                                           39                   8
# Albania                                               83                  23
# Algeria                                              126                  40
# Andorra                                                7                   0
# Angola                                                 4                   2
# ...                                                  ...                 ...
# Venezuela, Bolivarian Republic of...                  87                  28
# Viet Nam                                             220                  78
# Yemen                                                 17                   3
# Zambia                                                12                   4
# Zimbabwe                                              39                  14
#
# ...

# %%
data.calc
# Out:
# Country
# Afghanistan                             0.205128
# Albania                                 0.277108
# Algeria                                 0.317460
# Andorra                                 0.000000
# Angola                                  0.500000
#                                           ...
# Venezuela, Bolivarian Republic of...    0.321839
# Viet Nam                                0.354545
# Yemen                                   0.176471
# Zambia                                  0.333333
# Zimbabwe                                0.358974
# Name: calc, Length: 179, dtype: float64

# %% [markdown]
# df.dropna(axis='index/columns', how='any/all', subset=[list of columns], inplace=bool)
# df.replace('NA', np.nan, inplace=bool)
# df.isna()
# df.fillna()
# df.dtypes
# df/pds.astype()

# %%
df.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
df.YearsCode
# Out:
# 0          4
# 1        NaN
# 2          3
# 3          3
# 4         16
#         ...
# 88878    NaN
# 88879    NaN
# 88880    NaN
# 88881    NaN
# 88882      8
# Name: YearsCode, Length: 88883, dtype: object

# %%
df.YearsCode.dtypes
# Out:
# dtype('O')

# %%
type(df.YearsCode)
# Out:
# pandas.core.series.Series

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
df['YearsCode'].nunique()
# Out:
# 52

# %%
df.YearsCode.replace('Less than 1 year', 0, inplace=True)
df.YearsCode.replace('More than 50 years', 51, inplace=True)

# %%
df.YearsCode.astype(float)
# Out:
# 0         4.0
# 1         NaN
# 2         3.0
# 3         3.0
# 4        16.0
#          ...
# 88878     NaN
# 88879     NaN
# 88880     NaN
# 88881     NaN
# 88882     8.0
# Name: YearsCode, Length: 88883, dtype: float64

# %%
df['YearsCode'] = df.YearsCode.astype(float)

# %%
df.YearsCode.mean()
# Out:
# 11.662114216834588

# %%
df.YearsCode.median()
# Out:
# 9.0
