# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/sammy/Documents/active_ds-20221112T171807Z-001/active_ds/IMDB-Movie-Data.csv')

# %%
df.head(3)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
#
#                                          Description            Director  \
# 0  A group of intergalactic criminals are forced ...          James Gunn
# 1  Following clues to the origin of mankind, a te...        Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...  M. Night Shyamalan
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# ...

# %%
df.groupby('Year')['Metascore'].agg(np.median)
# Out:
# Year
# 2006    65.0
# 2007    65.5
# 2008    56.0
# 2009    57.0
# 2010    60.0
# 2011    63.0
# 2012    61.5
# 2013    60.0
# 2014    57.0
# 2015    56.0
# 2016    59.5
# Name: Metascore, dtype: float64

# %%
df.Year.dtypes
# Out:
# dtype('int64')

# %%
df.loc[~(df['Metascore']>=1), ['Year', 'Votes']].sort_values(by=['Year', 'Votes'], ascending=[True, False])
# Out:
#      Year   Votes
# 532  2006  253858
# 445  2006  184152
# 965  2006   44227
# 282  2007  220236
# 417  2007  202890
# ..    ...     ...
# 307  2016     403
# 605  2016     338
# 367  2016     286
# 25   2016     222
# 293  2016      96
#
# [64 rows x 2 columns]

# %%
df.query('Metascore<20')
#For columns with spaces in their name, you can use backtick quoting.
# Out:
#      Rank             Title                  Genre  \
# 49     50     The Last Face                  Drama
# 52     53      Mother's Day           Comedy,Drama
# 266   267     Dirty Grandpa                 Comedy
# 394   395       Grown Ups 2                 Comedy
# 508   509          Movie 43         Comedy,Romance
# 642   643  The Ridiculous 6         Comedy,Western
# 829   830    Disaster Movie                 Comedy
# 999  1000        Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 49   A director (Charlize Theron) of an internation...         Sean Penn
# 52   Three generations come together in the week le...    Garry Marshall
# 266  Right before his wedding, an uptight guy is tr...         Dan Mazer
# 394  After moving his family back to his hometown t...      Dennis Dugan
# 508  A series of interconnected short films follows...   Elizabeth Banks
# ...

# %%
pd.eval('twice_metascore = (df.Metascore**2)/32', target=df)
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
pd.eval('twice_metascore = (df.Metascore**2)/32', target=df, inplace=True)

# %%
df.query('~(twice_metascore < Metascore)')
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 995   996      Secret in Their Eyes       Crime,Drama,Mystery
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
